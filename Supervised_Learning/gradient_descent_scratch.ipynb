# %% [markdown]
# <a href="https://colab.research.google.com/github/ccarr-x/CMOR-438-SP-2026/blob/main/Supervised_Learning/gradient_descent_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Gradient Descent Optimization
#
# Gradient Descent is an iterative optimization algorithm used to find the location of the minimum value of a cost function. It works by calculating and searching the path directly opposite to the steepest path(gradient) of the function at the current location.
#
# The components of this model are:
# 1.  **The Cost Function:** The function of neuron error that we want to minimize.
# 2.  **Gradient:** The derivative of the cost function, indicating the direction and magnitude of the steepest path.
# 3.  **Learning Rate:** A hyperparameter that determines the size of the steps taken in the opposite direction of the gradient.
#
# The update rule for a function of one variable is then: `new_cost = current_cost - learning_rate * gradient(current_guess)`
#
# The update rule for a function of several variables is: `new_cost = current_cost - learning_rate * gradient(current_guess)`

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This expression defines a simple quadratic function that we can test optimization with: `f(x) = x^2 - 4x + 5`

# %%
def function(x):
    return x**2 - 4*x + 5

def gradient(x):
    # The derivative of x^2 - 4x + 5 = 2x - 4
    return 2*x - 4

# %% [markdown]
# Here, we will define the

# %%
def gradient_descent(starting_point, learning_rate, num_iterations):
    points_history = [starting_point]
    current_point = starting_point

    for _ in range(num_iterations):
        grad = gradient_of_function(current_point)
        current_point = current_point - learning_rate * grad
        points_history.append(current_point)

    return np.array(points_history)

# %% [markdown]
# Let's run the algorithm and visualize the steps.

# %%
# Parameters for Gradient Descent
starting_point = 10.0
learning_rate = 0.1
num_iterations = 20

# Run Gradient Descent
history = gradient_descent(starting_point, learning_rate, num_iterations)

# Generate x values for plotting the function
x_values = np.linspace(0, 10, 100)
y_values = function_to_optimize(x_values)

# Plot the function and the gradient descent steps
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='f(x) = x^2 - 4x + 5', color='blue')
plt.scatter(history, function_to_optimize(history), color='red', label='GD Steps', zorder=5)
plt.plot(history, function_to_optimize(history), color='red', linestyle='--', alpha=0.6)

plt.title('Gradient Descent Optimization')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

print(f"Final optimized x: {history[-1]:.4f}")
print(f"Minimum value of f(x): {function_to_optimize(history[-1]):.4f}")
# Out:
# Final optimized x: 2.0922
# Minimum value of f(x): 1.0085
